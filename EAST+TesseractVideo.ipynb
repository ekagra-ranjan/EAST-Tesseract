# %%
# USAGE
# python text_detection_video.py --east frozen_east_text_detection.pb

# import the necessary packages
from imutils.video import VideoStream
from imutils.video import FPS
from imutils.object_detection import non_max_suppression
import numpy as np
import argparse
import imutils
import time
import cv2
import pytesseract
import math

# %%
def decode_predictions(scores, geometry):
    # grab the number of rows and columns from the scores volume, then
    # initialize our set of bounding box rectangles and corresponding
    # confidence scores
    (numRows, numCols) = scores.shape[2:4]
    rects = []
    confidences = []

    # loop over the number of rows
    for y in range(0, numRows):
        # extract the scores (probabilities), followed by the
        # geometrical data used to derive potential bounding box
        # coordinates that surround text
        scoresData = scores[0, 0, y]
        xData0 = geometry[0, 0, y]
        xData1 = geometry[0, 1, y]
        xData2 = geometry[0, 2, y]
        xData3 = geometry[0, 3, y]
        anglesData = geometry[0, 4, y]

        # loop over the number of columns
        for x in range(0, numCols):
            # if our score does not have sufficient probability,
            # ignore it
            if scoresData[x] < args["min_confidence"]:
                continue

            # compute the offset factor as our resulting feature
            # maps will be 4x smaller than the input image
            (offsetX, offsetY) = (x * 4.0, y * 4.0)

            # extract the rotation angle for the prediction and
            # then compute the sin and cosine
            angle = anglesData[x]
            cos = np.cos(angle)
            sin = np.sin(angle)

            # use the geometry volume to derive the width and height
            # of the bounding box
            h = xData0[x] + xData2[x]
            w = xData1[x] + xData3[x]

            # compute both the starting and ending (x, y)-coordinates
            # for the text prediction bounding box
            endX = int(offsetX + (cos * xData1[x]) + (sin * xData2[x]))
            endY = int(offsetY - (sin * xData1[x]) + (cos * xData2[x]))
            startX = int(endX - w)
            startY = int(endY - h)

            # add the bounding box coordinates and probability score
            # to our respective lists
            rects.append((startX, startY, endX, endY))
            confidences.append(scoresData[x])

    # return a tuple of the bounding boxes and associated confidences
    return (rects, confidences)

# %%
# construct the argument parser and parse the arguments
# ap = argparse.ArgumentParser()
# ap.add_argument("-east", "--east", type=str, required=True,
# 	help="path to input EAST text detector")
# ap.add_argument("-v", "--video", type=str,
# 	help="path to optinal input video file")
# ap.add_argument("-c", "--min-confidence", type=float, default=0.5,
# 	help="minimum probability required to inspect a region")
# ap.add_argument("-w", "--width", type=int, default=320,
# 	help="resized image width (should be multiple of 32)")
# ap.add_argument("-e", "--height", type=int, default=320,
# 	help="resized image height (should be multiple of 32)")
# args = vars(ap.parse_args())

min_confidence = 0.2
width = 640
height = 640
args = { 'east' : './frozen_east_text_detection.pb', 
        'video' : './videos/faster.mp4',
        'min_confidence' : min_confidence,
        'width' : width, 
        'height' : height}

# %%
# initialize the original frame dimensions, new frame dimensions,
# and ratio between the dimensions
(W, H) = (None, None)
(newW, newH) = (args["width"], args["height"])
(rW, rH) = (None, None)

# define the two output layer names for the EAST detector model that
# we are interested -- the first is the output probabilities and the
# second can be used to derive the bounding box coordinates of text
layerNames = [
	"feature_fusion/Conv_7/Sigmoid",
	"feature_fusion/concat_3"]

# %%
# load the pre-trained EAST text detector
print("[INFO] loading EAST text detector...")
net = cv2.dnn.readNet(args["east"])
# Out:
# [INFO] loading EAST text detector...

# %%
# if a video path was not supplied, grab the reference to the web cam
if not args.get("video", False):
	print("[INFO] starting video stream...")
	vs = VideoStream(src=0).start()
	time.sleep(1.0)

# otherwise, grab a reference to the video file
else:
	vs = cv2.VideoCapture(args["video"])

# %%
# start the FPS throughput estimator
fps = FPS().start()

# loop over frames from the video stream
while True:
    # grab the current frame, then handle if we are using a
    # VideoStream or VideoCapture object
    frame = vs.read()
    frame = frame[1] if args.get("video", False) else frame

    # check to see if we have reached the end of the stream
    if frame is None:
        break

    # resize the frame, maintaining the aspect ratio
    frame = imutils.resize(frame, width=1000)
    orig = frame.copy()

    # if our frame dimensions are None, we still need to compute the
    # ratio of old frame dimensions to new frame dimensions
    if W is None or H is None:
        (H, W) = frame.shape[:2]
        rW = W / float(newW)
        rH = H / float(newH)

    # resize the frame, this time ignoring aspect ratio
    frame = cv2.resize(frame, (newW, newH))

    # construct a blob from the frame and then perform a forward pass
    # of the model to obtain the two output layer sets
    blob = cv2.dnn.blobFromImage(frame, 1.0, (newW, newH),
        (123.68, 116.78, 103.94), swapRB=True, crop=False)
    net.setInput(blob)
    (scores, geometry) = net.forward(layerNames)

    # decode the predictions, then  apply non-maxima suppression to
    # suppress weak, overlapping bounding boxes
    (rects, confidences) = decode_predictions(scores, geometry)
    boxes = non_max_suppression(np.array(rects), probs=confidences)

    # loop over the bounding boxes
    #---Tesseract 
    tesseractOutputImage = np.zeros_like(orig)
    origTesseract = orig.copy()
    for (startX, startY, endX, endY) in boxes:
        # scale the bounding box coordinates based on the respective
        # ratios
        startX = int(startX * rW)
        startY = int(startY * rH)
        endX = int(endX * rW)
        endY = int(endY * rH)

        #----tessaract
        extraPixelsX = 0.99
        extraPixelsY = 0.90
        croppedImage = origTesseract[int(startY*extraPixelsY):int(endY/extraPixelsY), int(startX*extraPixelsX):int(endX/extraPixelsX)]
        config = ('-l eng --oem 3 --psm 6')
        text = pytesseract.image_to_string(croppedImage, config=config).encode('utf-8')
        print(startX, startY, endX, endY)
        textScale = (2.0*(endX-startX)/200.0)/(len(text)+0.002)*5
        textThickness = max(4*(endX-startX)/200/(len(text)+1)*4, 0)
        print("Text Scale: ", textScale)
        print("Text Thickness: ", textThickness)
        cv2.putText(tesseractOutputImage, str(text), (startX,endY), cv2.FONT_HERSHEY_SIMPLEX, textScale, (0, 255, 0), textThickness, lineType = cv2.LINE_AA)
    #         plt.imshow(croppedImage)
    #         plt.show()
        print("Text:", str(text))


    for (startX, startY, endX, endY) in boxes:
        # scale the bounding box coordinates based on the respective
        # ratios
        startX = int(startX * rW)
        startY = int(startY * rH)
        endX = int(endX * rW)
        endY = int(endY * rH)

        # draw the bounding box on the frame
        cv2.rectangle(orig, (startX, startY), (endX, endY), (0, 255, 0), 2)

    # update the FPS counter
    fps.update()

    # show the output frame
    cv2.imshow("Text Detection", orig)
    cv2.imshow("Text recognition", tesseractOutputImage)
    key = cv2.waitKey(1) & 0xFF

    # if the `q` key was pressed, break from the loop
    if key == ord("q"):
        break

# stop the timer and display FPS information
fps.stop()
print("[INFO] elasped time: {:.2f}".format(fps.elapsed()))
print("[INFO] approx. FPS: {:.2f}".format(fps.fps()))

# if we are using a webcam, release the pointer
if not args.get("video", False):
    vs.stop()

# otherwise, release the file pointer
else:
    vs.release()

# close all windows
cv2.destroyAllWindows()
# Out:
# (643, 94, 723, 110)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (725, 93, 809, 111)
# ('Text Scale: ', 0.46656298600311036)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', '+,')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (296, 85, 382, 109)
# ('Text Scale: ', 0.25291142218562523)
# ('Text Thickness: ', 0)
# ('Text:', 'eeneeennem\neT HIF')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.24207978107567626)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai) Ta ot\nes')
# (221, 36, 693, 71)
# ('Text Scale: ', 0.9832513957170236)
# ('Text Thickness: ', 0)
# ('Text:', '@\xc2\xae tAkshavSpeaksToArnab')
# (400, 87, 546, 109)
# ('Text Scale: ', 0.6082319613397766)
# ('Text Thickness: ', 0)
# ('Text:', 'NEWSY INTERV')
# (364, 391, 528, 420)
# ('Text Scale: ', 0.5465937874950006)
# ('Text Thickness: ', 0)
# ('Text:', 'atu\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.8396641343462614)
# ('Text Thickness: ', 0)
# ('Text:', 'ay\nen')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (190, 84, 234, 113)
# ('Text Scale: ', 0.24439013552543878)
# ('Text Thickness: ', 0)
# ('Text:', 'ir\n\xe2\x80\x94\xe2\x80\x94')
# (593, 89, 632, 111)
# ('Text Scale: ', 0.9740259740259742)
# ('Text Thickness: ', 0)
# ('Text:', 'Ls')
# (650, 390, 703, 417)
# ('Text Scale: ', 0.5297880847660936)
# ('Text Thickness: ', 0)
# ('Text:', 'ae\nTO')
# (643, 94, 723, 110)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (725, 94, 809, 111)
# ('Text Scale: ', 0.46656298600311036)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION')
# (703, 391, 810, 419)
# ('Text Scale: ', 0.891369543485505)
# ('Text Thickness: ', 0)
# ('Text:', 'tr. Te')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (298, 85, 384, 109)
# ('Text Scale: ', 0.26871641044869393)
# ('Text Thickness: ', 0)
# ('Text:', 'eneeennen\neT HIF')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.24207978107567626)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai) Ta ot\nes')
# (223, 36, 693, 71)
# ('Text Scale: ', 1.0680847195709482)
# ('Text Thickness: ', 0)
# ('Text:', '@ #AkshavSpeaksToArnab')
# (403, 87, 589, 108)
# ('Text Scale: ', 0.6199173443540861)
# ('Text Thickness: ', 0)
# ('Text:', 'NEWSY INTERVIEW')
# (364, 391, 528, 420)
# ('Text Scale: ', 0.5856306241965433)
# ('Text Thickness: ', 0)
# ('Text:', 'eeu\nSUPER EXCL')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.8396641343462614)
# ('Text Thickness: ', 0)
# ('Text:', 'ay\nen')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (190, 84, 232, 112)
# ('Text Scale: ', 0.6995336442371752)
# ('Text Thickness: ', 0)
# ('Text:', 'tt:')
# (643, 94, 723, 110)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.4554543434792268)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', 'To')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.5680785311761498)
# ('Text Thickness: ', 0)
# ('Text:', 'PEAGCLUSIVE')
# (298, 86, 384, 109)
# ('Text Scale: ', 0.2047424054851919)
# ('Text Thickness: ', 0)
# ('Text:', 'eannuenneneent\neT HIF')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.24207978107567626)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai) Ta ot\nes')
# (223, 36, 693, 71)
# ('Text Scale: ', 1.0680847195709482)
# ('Text Thickness: ', 0)
# ('Text:', '@ #AkshavSpeaksToArnab')
# (400, 87, 589, 108)
# ('Text Scale: ', 0.8589347391383384)
# ('Text Thickness: ', 0)
# ('Text:', 'NEWS) Aaa 1')
# (364, 391, 528, 420)
# ('Text Scale: ', 0.5856306241965433)
# ('Text Thickness: ', 0)
# ('Text:', 'ou\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.8396641343462614)
# ('Text Thickness: ', 0)
# ('Text:', 'ay\nen')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 0.4198320671731307)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\na')
# (643, 94, 723, 110)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', 'To')
# (298, 86, 384, 109)
# ('Text Scale: ', 0.8596561375449819)
# ('Text Thickness: ', 0)
# ('Text:', 'Pt\nri')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.24207978107567626)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai) Ta ot\nes')
# (225, 36, 693, 71)
# ('Text Scale: ', 1.0173028432310234)
# ('Text Thickness: ', 0)
# ('Text:', 'a) tAkshavSpeaksToArnab')
# (398, 87, 587, 109)
# ('Text Scale: ', 2.3613193403298354)
# ('Text Thickness: ', 0)
# ('Text:', 'Nisa')
# (365, 391, 528, 420)
# ('Text Scale: ', 0.5432608985468603)
# ('Text Thickness: ', 0)
# ('Text:', 'aoa\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 0.20995800839832032)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\n\xe2\x80\x94\xe2\x80\x94')
# (643, 94, 721, 110)
# ('Text Scale: ', 1950.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 1.7654896735509662)
# ('Text Thickness: ', 0)
# ('Text:', 'tr.')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.24207978107567626)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai) Ta ot\nes')
# (298, 85, 384, 109)
# ('Text Scale: ', 0.2866284495400613)
# ('Text Thickness: ', 0)
# ('Text:', 'eneeennen\neT Ie')
# (226, 36, 693, 71)
# ('Text Scale: ', 0.44902119149263486)
# ('Text Thickness: ', 0)
# ('Text:', 'i tte KSI\nHAKSH 21 S| AAC | a\n) #AkshaySpeaksToArnab')
# (398, 87, 589, 109)
# ('Text Scale: ', 1.5911362879040318)
# ('Text Thickness: ', 0)
# ('Text:', 'Navara')
# (367, 391, 528, 420)
# ('Text Scale: ', 0.5030621172353457)
# ('Text Thickness: ', 0)
# ('Text:', 'mois\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 0.6995336442371752)
# ('Text Thickness: ', 0)
# ('Text:', 'THE')
# (645, 94, 723, 110)
# ('Text Scale: ', 1950.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.4099180163967206)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x9cEDITION')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', '+,')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.24207978107567626)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai) Ta ot\nes')
# (296, 85, 384, 109)
# ('Text Scale: ', 0.8796481407437027)
# ('Text Thickness: ', 0)
# ('Text:', 'Py\nri')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.0567221161712572)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (396, 87, 589, 109)
# ('Text Scale: ', 0.6030496187976503)
# ('Text Thickness: ', 0)
# ('Text:', 'rie ra INTERVIEW')
# (367, 391, 528, 420)
# ('Text Scale: ', 0.5030621172353457)
# ('Text Thickness: ', 0)
# ('Text:', 'meas\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 111)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 1.048951048951049)
# ('Text Thickness: ', 0)
# ('Text:', 'ie')
# (650, 390, 703, 417)
# ('Text Scale: ', 0.33116720819795054)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x94-\nTOs')
# (643, 94, 723, 110)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', 'Po')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'pEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.24207978107567626)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai) Ta ot\nes')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.0567221161712572)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (298, 85, 385, 109)
# ('Text Scale: ', 2.172827172827173)
# ('Text Thickness: ', 0)
# ('Text:', 'my')
# (396, 87, 589, 109)
# ('Text Scale: ', 2.4112943528235884)
# ('Text Thickness: ', 0)
# ('Text:', 'Tava')
# (365, 391, 528, 420)
# ('Text Scale: ', 0.4793553699564757)
# ('Text Thickness: ', 0)
# ('Text:', 'amass\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 1.048951048951049)
# ('Text Thickness: ', 0)
# ('Text:', 'fe')
# (643, 94, 723, 110)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', 'Po')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'pEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.22997700229977006)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai 0) Todt\nes')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.1623837616238377)
# ('Text Thickness: ', 0)
# ('Text:', 'tAkshaySpeaksToArnab')
# (298, 85, 384, 109)
# ('Text Scale: ', 0.26871641044869393)
# ('Text Thickness: ', 0)
# ('Text:', 'eraeuneneest\nTIF')
# (395, 87, 589, 109)
# ('Text Scale: ', 0.6061742282214724)
# ('Text Thickness: ', 0)
# ('Text:', 'NEWSY INTERVIEW.')
# (364, 391, 528, 420)
# ('Text Scale: ', 0.45550494389512275)
# ('Text Thickness: ', 0)
# ('Text:', 'zzz be\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 1.048951048951049)
# ('Text Thickness: ', 0)
# ('Text:', 'it')
# (515, 125, 778, 187)
# ('Text Scale: ', 6575.0)
# ('Text Thickness: ', 20)
# ('Text:', '')
# (650, 390, 703, 417)
# ('Text Scale: ', 0.5297880847660936)
# ('Text Thickness: ', 0)
# ('Text:', 'a\nTOs')
# (643, 95, 723, 111)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', 'Pi')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'pEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.22997700229977006)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai 0) Todt\nes')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.1623837616238377)
# ('Text Thickness: ', 0)
# ('Text:', 'tAkshaySpeaksToArnab')
# (296, 85, 384, 109)
# ('Text Scale: ', 0.7330889703432188)
# ('Text Thickness: ', 0)
# ('Text:', 'SL\nTIF')
# (396, 87, 589, 109)
# ('Text Scale: ', 0.6432475669910678)
# ('Text Thickness: ', 0)
# ('Text:', 'NEWSY INTERVIEW')
# (364, 391, 528, 420)
# ('Text Scale: ', 0.4822962004470063)
# ('Text Thickness: ', 0)
# ('Text:', 'zz be\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (193, 84, 234, 112)
# ('Text Scale: ', 0.2927734932876321)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\n\xe2\x80\x94')
# (531, 126, 778, 187)
# ('Text Scale: ', 6175.0)
# ('Text Thickness: ', 16)
# ('Text:', '')
# (643, 95, 723, 111)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.4554543434792268)
# ('Text Thickness: ', 0)
# ('Text:', '5 EDITION')
# (535, 390, 657, 418)
# ('Text Scale: ', 0.6776271939568984)
# ('Text Thickness: ', 0)
# ('Text:', 'ace\nUSIVE')
# (704, 391, 810, 419)
# ('Text Scale: ', 2.6473526473526476)
# ('Text Thickness: ', 0)
# ('Text:', 'To')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.22997700229977006)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai 0) Todt\nes')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.1623837616238377)
# ('Text Thickness: ', 0)
# ('Text:', 'tAkshaySpeaksToArnab')
# (298, 85, 385, 109)
# ('Text Scale: ', 0.21747825217478253)
# ('Text Thickness: ', 0)
# ('Text:', 'ernennemnenns\neT HIF')
# (396, 87, 589, 109)
# ('Text Scale: ', 3.214523650899401)
# ('Text Thickness: ', 0)
# ('Text:', 'TBM')
# (370, 391, 528, 420)
# ('Text Scale: ', 0.4646512175038231)
# ('Text Thickness: ', 0)
# ('Text:', 'ee ee\nSUPER EACLI')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 0.6995336442371752)
# ('Text Thickness: ', 0)
# ('Text:', 'THE')
# (539, 127, 779, 189)
# ('Text Scale: ', 2.9985007496251876)
# ('Text Thickness: ', 0)
# ('Text:', 'i. ,')
# (592, 89, 631, 110)
# ('Text Scale: ', 0.6495669553630913)
# ('Text Thickness: ', 0)
# ('Text:', 'Ti.')
# (650, 390, 703, 417)
# ('Text Scale: ', 0.33116720819795054)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x94-\nTOs')
# (643, 95, 723, 111)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (535, 391, 659, 419)
# ('Text Scale: ', 0.6887358364807821)
# ('Text Thickness: ', 0)
# ('Text:', 'yee\nUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.22997700229977006)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai 0) Todt\nes')
# (465, 430, 590, 450)
# ('Text Scale: ', 0.6248750249950009)
# ('Text Thickness: ', 0)
# ('Text:', 'pEACLUSIVE')
# (296, 86, 384, 110)
# ('Text Scale: ', 0.4399120175964807)
# ('Text Thickness: ', 0)
# ('Text:', 'ryt\nCANDID')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.1623837616238377)
# ('Text Thickness: ', 0)
# ('Text:', 'tAkshaySpeaksToArnab')
# (373, 390, 528, 419)
# ('Text Scale: ', 0.4843144606924135)
# ('Text Thickness: ', 0)
# ('Text:', 'oats\nSUPER EACLI')
# (396, 87, 589, 109)
# ('Text Scale: ', 2.4112943528235884)
# ('Text Thickness: ', 0)
# ('Text:', 'MaMa')
# (387, 429, 471, 450)
# ('Text Scale: ', 0.5998286203941731)
# ('Text Thickness: ', 0)
# ('Text:', 'Va\n\xe2\x80\x94_')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (193, 85, 234, 112)
# ('Text Scale: ', 0.40983606557377045)
# ('Text Thickness: ', 0)
# ('Text:', '3\n\xe2\x80\x94')
# (553, 129, 775, 189)
# ('Text Scale: ', 5550.0)
# ('Text Thickness: ', 16)
# ('Text:', '')
# (593, 89, 632, 110)
# ('Text Scale: ', 1.9461077844311379)
# ('Text Thickness: ', 0)
# ('Text:', 'r')
# (643, 95, 725, 111)
# ('Text Scale: ', 2049.9999999999995)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.4554543434792268)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION')
# (465, 431, 592, 450)
# ('Text Scale: ', 0.634873025394921)
# ('Text Thickness: ', 0)
# ('Text:', 'pEACLUSIVE')
# (292, 432, 384, 450)
# ('Text Scale: ', 0.22997700229977006)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nsai 0) Todt\nes')
# (296, 86, 384, 110)
# ('Text Scale: ', 0.7330889703432188)
# ('Text Thickness: ', 0)
# ('Text:', 'CANDID')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.1070374250071422)
# ('Text Thickness: ', 0)
# ('Text:', 'tAkshavySpeaksToArnab')
# (398, 87, 589, 109)
# ('Text Scale: ', 1.5911362879040318)
# ('Text Thickness: ', 0)
# ('Text:', 'Ma Mea')
# (373, 391, 545, 420)
# ('Text Scale: ', 0.5374328208973879)
# ('Text Thickness: ', 0)
# ('Text:', 'Bea\nSUPER EACLUS')
# (387, 430, 470, 450)
# ('Text Scale: ', 1.0369815092453774)
# ('Text Thickness: ', 0)
# ('Text:', 'A\nae')
# (235, 86, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 0.6995336442371752)
# ('Text Thickness: ', 0)
# ('Text:', 'THE')
# (548, 130, 770, 188)
# ('Text Scale: ', 5.544455544455546)
# ('Text Thickness: ', 4)
# ('Text:', 'la')
# (593, 89, 632, 110)
# ('Text Scale: ', 0.487256371814093)
# ('Text Thickness: ', 0)
# ('Text:', '_\xe2\x80\x94')
# (643, 95, 723, 111)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.4554543434792268)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION')
# (290, 432, 382, 450)
# ('Text Scale: ', 0.3285244965004999)
# ('Text Thickness: ', 0)
# ('Text:', 'AKSHA\nToate\nes')
# (465, 431, 592, 450)
# ('Text Scale: ', 0.634873025394921)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (389, 429, 470, 449)
# ('Text Scale: ', 0.2892443936580489)
# ('Text Thickness: ', 0)
# ('Text:', 'i\nSUPER |\n\xe2\x80\x94)')
# (229, 36, 693, 71)
# ('Text Scale: ', 1.1046566993619655)
# ('Text Thickness: ', 0)
# ('Text:', 'tAkshavySpeaksToArnab')
# (295, 85, 384, 110)
# ('Text Scale: ', 0.4943345923128194)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x98CANDID')
# (398, 87, 589, 109)
# ('Text Scale: ', 0.5968003999500062)
# ('Text Thickness: ', 0)
# ('Text:', 'NEWSY INTERVIEW.')
# (279, 388, 407, 419)
# ('Text Scale: ', 1.5992003998001)
# ('Text Thickness: ', 0)
# ('Text:', 'a\nsi')
# (235, 86, 292, 110)
# ('Text Scale: ', 1424.9999999999998)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 112)
# ('Text Scale: ', 0.6995336442371752)
# ('Text Thickness: ', 0)
# ('Text:', 'THE')
# (535, 130, 770, 189)
# ('Text Scale: ', 2.3490603758496604)
# ('Text Thickness: ', 0)
# ('Text:', 'J \\ |')
# (592, 89, 632, 110)
# ('Text Scale: ', 0.9990009990009991)
# ('Text Thickness: ', 0)
# ('Text:', 'eT')
# (643, 95, 725, 111)
# ('Text Scale: ', 2049.9999999999995)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (295, 432, 385, 449)
# ('Text Scale: ', 0.5623594101474632)
# ('Text Thickness: ', 0)
# ('Text:', 'Taro\nee,')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (387, 430, 470, 449)
# ('Text Scale: ', 1.3824117255163224)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x94')
# (465, 431, 592, 450)
# ('Text Scale: ', 0.634873025394921)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (296, 85, 384, 110)
# ('Text Scale: ', 0.7330889703432188)
# ('Text Thickness: ', 0)
# ('Text:', 'CANDID')
# (231, 36, 693, 71)
# ('Text Scale: ', 1.0499045541314427)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (396, 87, 589, 109)
# ('Text Scale: ', 0.6432475669910678)
# ('Text Thickness: ', 0)
# ('Text:', 'NEWSY INTERVIEW')
# (237, 86, 295, 110)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 84, 234, 112)
# ('Text Scale: ', 0.4198320671731307)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\na')
# (542, 129, 768, 188)
# ('Text Scale: ', 3.764157228514324)
# ('Text Thickness: ', 4)
# ('Text:', '_ |')
# (592, 89, 632, 110)
# ('Text Scale: ', 1.996007984031936)
# ('Text Thickness: ', 0)
# ('Text:', 'a')
# (643, 95, 723, 111)
# ('Text Scale: ', 0.7996801279488206)
# ('Text Thickness: ', 0)
# ('Text:', 'SPS |')
# (295, 432, 385, 449)
# ('Text Scale: ', 0.5623594101474632)
# ('Text Thickness: ', 0)
# ('Text:', 'Taro\nee,')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (387, 430, 470, 449)
# ('Text Scale: ', 1.3824117255163224)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x94')
# (465, 431, 592, 450)
# ('Text Scale: ', 0.634873025394921)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (298, 85, 384, 110)
# ('Text Scale: ', 0.716427857380873)
# ('Text Thickness: ', 0)
# ('Text:', 'PTT\nrh')
# (231, 36, 693, 71)
# ('Text Scale: ', 1.0499045541314427)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (398, 87, 589, 109)
# ('Text Scale: ', 1.5911362879040318)
# ('Text Thickness: ', 0)
# ('Text:', 'Ma. AM')
# (235, 86, 295, 111)
# ('Text Scale: ', 1500.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (192, 85, 234, 113)
# ('Text Scale: ', 0.29991431019708653)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\n\xe2\x80\x94')
# (532, 127, 767, 187)
# ('Text Scale: ', 5.86913086913087)
# ('Text Thickness: ', 4)
# ('Text:', '2S')
# (592, 89, 632, 110)
# ('Text Scale: ', 1.996007984031936)
# ('Text Thickness: ', 0)
# ('Text:', 'a')
# (643, 95, 723, 111)
# ('Text Scale: ', 0.7996801279488206)
# ('Text Thickness: ', 0)
# ('Text:', 'Seu |')
# (725, 94, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (295, 432, 385, 449)
# ('Text Scale: ', 0.44991001799640074)
# ('Text Thickness: ', 0)
# ('Text:', '}\nTaro\nee,')
# (387, 430, 470, 449)
# ('Text Scale: ', 1.3824117255163224)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x94')
# (465, 431, 592, 450)
# ('Text Scale: ', 0.634873025394921)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (231, 36, 693, 71)
# ('Text Scale: ', 1.0499045541314427)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (298, 86, 384, 110)
# ('Text Scale: ', 0.5373656585853536)
# ('Text Thickness: ', 0)
# ('Text:', 'Py\nANDID')
# (398, 87, 587, 109)
# ('Text Scale: ', 1.8892443022790884)
# ('Text Thickness: ', 0)
# ('Text:', 'a. AM')
# (235, 86, 293, 111)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (190, 85, 234, 113)
# ('Text Scale: ', 0.21995600879824034)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\n\xe2\x80\x94\xe2\x80\x94')
# (518, 124, 768, 186)
# ('Text Scale: ', 1.5621094726318419)
# ('Text Thickness: ', 0)
# ('Text:', 'RS\nI \\ |')
# (592, 89, 632, 110)
# ('Text Scale: ', 1.996007984031936)
# ('Text Thickness: ', 0)
# ('Text:', 'a')
# (642, 95, 723, 112)
# ('Text Scale: ', 2025.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (723, 93, 807, 111)
# ('Text Scale: ', 0.38174877295037263)
# ('Text Thickness: ', 0)
# ('Text:', 'L EDITION |')
# (292, 432, 385, 450)
# ('Text Scale: ', 0.5165518773605865)
# ('Text Thickness: ', 0)
# ('Text:', 'is\neae\nes')
# (387, 429, 470, 449)
# ('Text Scale: ', 1.3824117255163224)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x94')
# (465, 431, 592, 450)
# ('Text Scale: ', 0.634873025394921)
# ('Text Thickness: ', 0)
# ('Text:', 'pEACLUSIVE')
# (231, 36, 693, 71)
# ('Text Scale: ', 1.0499045541314427)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (396, 87, 587, 109)
# ('Text Scale: ', 2.3863068465767117)
# ('Text Thickness: ', 0)
# ('Text:', 'MaMa')
# (296, 85, 384, 110)
# ('Text Scale: ', 0.5498625343664083)
# ('Text Thickness: ', 0)
# ('Text:', 'a\nCANDID')
# (281, 389, 356, 421)
# ('Text Scale: ', 3.7425149700598803)
# ('Text Thickness: ', 0)
# ('Text:', '=')
# (235, 86, 293, 111)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (190, 84, 232, 112)
# ('Text Scale: ', 0.6995336442371752)
# ('Text Thickness: ', 0)
# ('Text:', 'it:')
# (551, 129, 757, 185)
# ('Text Scale: ', 0.3322366298948455)
# ('Text Thickness: ', 0)
# ('Text:', '\xe2\x80\x94_\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\xe2\x80\x94\nLo')
# (590, 89, 632, 110)
# ('Text Scale: ', 2.095808383233533)
# ('Text Thickness: ', 0)
# ('Text:', 'a')
# (643, 95, 723, 112)
# ('Text Scale: ', 2000.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 93, 807, 111)
# ('Text Scale: ', 0.3726595164515542)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION |')
# (290, 432, 384, 450)
# ('Text Scale: ', 0.3356663333809456)
# ('Text Thickness: ', 0)
# ('Text:', 'SUPERS\noad\nez,')
# (464, 431, 592, 450)
# ('Text Scale: ', 0.5817124159243774)
# ('Text Thickness: ', 0)
# ('Text:', 'LEAGCLUSIVE')
# (229, 36, 693, 71)
# ('Text Scale: ', 1.054449595491319)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (298, 86, 384, 110)
# ('Text Scale: ', 0.614110254213082)
# ('Text Thickness: ', 0)
# ('Text:', 'anes\nai')
# (396, 87, 587, 109)
# ('Text Scale: ', 4774.999999999999)
# ('Text Thickness: ', 12)
# ('Text:', '')
# (387, 429, 470, 449)
# ('Text Scale: ', 0.8296681327469012)
# ('Text Thickness: ', 0)
# ('Text:', 'I)\nae')
# (279, 389, 439, 418)
# ('Text Scale: ', 1.332889036987671)
# ('Text Thickness: ', 0)
# ('Text:', 'a\nSUPE')
# (235, 86, 293, 111)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (193, 85, 234, 112)
# ('Text Scale: ', 1.023976023976024)
# ('Text Thickness: ', 0)
# ('Text:', 'm3')
# (550, 129, 751, 185)
# ('Text Scale: ', 1.0047990401919613)
# ('Text Thickness: ', 0)
# ('Text:', 'a\nRe dette')
# (642, 95, 723, 112)
# ('Text Scale: ', 2025.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 94, 806, 111)
# ('Text Scale: ', 0.44990002221728503)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION')
# (290, 432, 384, 450)
# ('Text Scale: ', 0.46990601879624067)
# ('Text Thickness: ', 0)
# ('Text:', 'it\noad\nez,')
# (464, 430, 592, 450)
# ('Text Scale: ', 0.639872025594881)
# ('Text Thickness: ', 0)
# ('Text:', 'LEACLUSIVE')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.0567221161712572)
# ('Text Thickness: ', 0)
# ('Text:', 'a tAkshaySpeaksToArnab')
# (298, 85, 384, 110)
# ('Text Scale: ', 0.5373656585853536)
# ('Text Thickness: ', 0)
# ('Text:', 'Py\nANDID')
# (395, 87, 587, 109)
# ('Text Scale: ', 4800.0)
# ('Text Thickness: ', 12)
# ('Text:', '')
# (387, 429, 471, 449)
# ('Text Scale: ', 0.46656298600311036)
# ('Text Thickness: ', 0)
# ('Text:', 'TENE:\n\xe2\x80\x94')
# (454, 390, 520, 418)
# ('Text Scale: ', 0.2356806170547065)
# ('Text Thickness: ', 0)
# ('Text:', 'Ball Ka\nR EAGL')
# (273, 389, 457, 419)
# ('Text Scale: ', 0.6132515664578055)
# ('Text Thickness: ', 0)
# ('Text:', '_ aw 2\nSe\nSUPER')
# (235, 86, 293, 111)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (193, 85, 234, 112)
# ('Text Scale: ', 0.40983606557377045)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\na')
# (556, 131, 748, 186)
# ('Text Scale: ', 0.6399146780429276)
# ('Text Thickness: ', 0)
# ('Text:', 'b=\nDabedeiieten')
# (643, 95, 725, 112)
# ('Text Scale: ', 2049.9999999999995)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (725, 93, 806, 111)
# ('Text Scale: ', 0.44990002221728503)
# ('Text Thickness: ', 0)
# ('Text:', '. EDITION')
# (290, 432, 384, 450)
# ('Text Scale: ', 0.46990601879624067)
# ('Text Thickness: ', 0)
# ('Text:', 'it\noad\nez,')
# (457, 389, 578, 419)
# ('Text Scale: ', 0.35584048935419366)
# ('Text Thickness: ', 0)
# ('Text:', 'bo oe\nR EACLUSIVE')
# (296, 85, 385, 109)
# ('Text Scale: ', 0.2617339136572168)
# ('Text Thickness: ', 0)
# ('Text:', 'nareenemnense\nwhi')
# (228, 36, 693, 71)
# ('Text Scale: ', 1.0567221161712572)
# ('Text Thickness: ', 0)
# ('Text:', '@ tAkshaySpeaksToArnab')
# (464, 430, 592, 450)
# ('Text Scale: ', 0.639872025594881)
# ('Text Thickness: ', 0)
# ('Text:', 'LEACLUSIVE')
# (398, 87, 589, 109)
# ('Text Scale: ', 4774.999999999999)
# ('Text Thickness: ', 12)
# ('Text:', '')
# (387, 429, 470, 449)
# ('Text Scale: ', 0.4149170165966806)
# ('Text Thickness: ', 0)
# ('Text:', 'STAR A\n\xe2\x80\x94')
# (273, 389, 457, 419)
# ('Text Scale: ', 0.5110543272969671)
# ('Text Thickness: ', 0)
# ('Text:', '_  \xe2\x80\x94\xe2\x80\x94_ |\nSUPER')
# (235, 86, 293, 111)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (193, 85, 234, 112)
# ('Text Scale: ', 0.40983606557377045)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\na')
# (557, 131, 745, 186)
# ('Text Scale: ', 1.342473578977435)
# ('Text Thickness: ', 0)
# ('Text:', '_\nre\nTT')
# (643, 94, 725, 111)
# ('Text Scale: ', 2049.9999999999995)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (723, 93, 806, 111)
# ('Text Scale: ', 0.46100866474116853)
# ('Text Thickness: ', 0)
# ('Text:', 'L EDITION')
# (290, 432, 384, 450)
# ('Text Scale: ', 0.3356663333809456)
# ('Text Thickness: ', 0)
# ('Text:', 'SUPERS\noad\nez,')
# (226, 36, 693, 71)
# ('Text Scale: ', 1.0612671575311337)
# ('Text Thickness: ', 0)
# ('Text:', '@ #AkshaySpeaksToArnab')
# (465, 430, 592, 450)
# ('Text Scale: ', 0.634873025394921)
# ('Text Thickness: ', 0)
# ('Text:', 'PEACLUSIVE')
# (296, 86, 384, 110)
# ('Text Scale: ', 0.3999272859480094)
# ('Text Thickness: ', 0)
# ('Text:', 'nome\nCANDID')
# (398, 86, 587, 108)
# ('Text Scale: ', 3.147901399067288)
# ('Text Thickness: ', 0)
# ('Text:', 'sea')
# (387, 429, 470, 449)
# ('Text Scale: ', 0.4149170165966806)
# ('Text Thickness: ', 0)
# ('Text:', 'STAR A\n\xe2\x80\x94')
# (273, 389, 456, 419)
# ('Text Scale: ', 0.7623729378436928)
# ('Text Thickness: ', 0)
# ('Text:', "\xe2\x80\x94\ni '\nSUPE")
# (235, 87, 293, 112)
# ('Text Scale: ', 1450.0)
# ('Text Thickness: ', 4)
# ('Text:', '')
# (456, 390, 628, 420)
# ('Text Scale: ', 0.6141979717183259)
# ('Text Thickness: ', 0)
# ('Text:', 'no\nR EACLUSIVE')
# (192, 85, 234, 112)
# ('Text Scale: ', 0.20995800839832032)
# ('Text Thickness: ', 0)
# ('Text:', 'THE\n\xe2\x80\x94\xe2\x80\x94')
# (554, 130, 742, 185)
# ('Text Scale: ', 0.9398120375924813)
# ('Text Thickness: ', 0)
# ('Text:', "ere\nj '? '")
# [INFO] elasped time: 63.63
# [INFO] approx. FPS: 0.33
